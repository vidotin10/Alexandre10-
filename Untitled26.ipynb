# %% [markdown]
# <a href="https://colab.research.google.com/github/vidotin10/Alexandre10-/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ativida em dupla: Alexandre Vidoto Pereira e Pedro Henrique Ferreira Piana

# %%
#1 Crie um algoritmo que simule um sistema de reservas de um restaurante. O programa deve solicitar o número de pessoas para a reserva e verificar se há disponibilidade, considerando que o restaurante possui apenas mesas de 4 lugares. Se o número de pessoas exceder a capacidade de uma mesa, o programa deve calcular quantas mesas serão necessárias e informar ao usuário.
mesas = 5
lugares = mesas * 4

while True:
    reservas = int(input('Quantidade de pessoas: '))

    if reservas <= lugares:
        mesas_necessarias = reservas // 4
        if reservas % 4 != 0:
            mesas_necessarias += 1
            pessoas_ajustadas = mesas_necessarias * 4
        else:
            pessoas_ajustadas = reservas

        if mesas_necessarias <= mesas:
            print(f'Foi reservado {mesas_necessarias} mesas para {reservas} pessoas')
            mesas -= mesas_necessarias
            lugares -= pessoas_ajustadas
            print(f'Ainda restam {mesas} mesas com {lugares} lugares.')
        else:
            print(f'Não há mesas suficientes para acomodar {reservas} pessoas.')
            print(f'Só restam {mesas} mesas com {lugares} lugares.')
    else:
        print(f'Não comporta, só restam {mesas} mesas com {lugares} lugares.')

    opc = input('Deseja continuar? (S/N) ')
    if opc.upper() == 'N':
        print('Tchau!')
        break
# Out:
# Quantidade de pessoas: 50
# Não comporta, só restam 5 mesas com 20 lugares.
# Deseja continuar? (S/N) s
# Quantidade de pessoas: 100
# Não comporta, só restam 5 mesas com 20 lugares.
# Deseja continuar? (S/N) s
# Quantidade de pessoas: 20
# Foi reservado 5 mesas para 20 pessoas
# Ainda restam 0 mesas com 0 lugares.
# Deseja continuar? (S/N) n
# Tchau!

# %%
#2 Desenvolva um algoritmo que auxilie na gestão de estoque de uma loja. O programa deve permitir que o usuário insira o nome e a quantidade de diferentes produtos. Se a quantidade de um produto for inferior a 5 unidades, o sistema deve alertar que o estoque está baixo e sugerir a reposição. O processo deve continuar até que o usuário decida encerrar.
def gerenciar_estoque():
    estoque = {}
    while True:
        produto = input("Digite o nome do produto: ").strip()
        try:
            quantidade = int(input(f"Digite a quantidade de '{produto}': "))
        except ValueError:
            print("Por favor, insira um número válido para a quantidade.")
            continue
        estoque[produto] = quantidade
        if quantidade < 5:
            print(f"Alerta: o estoque de '{produto}' está baixo ({quantidade} unidades). Considere fazer uma reposição.")


        continuar = input("Deseja adicionar outro produto? (s/n): ").strip().lower()
        if continuar != 's':
            print("Encerrando o gerenciamento de estoque.")
            break


    print("\nEstoque final:")
    for produto, quantidade in estoque.items():
        print(f"{produto}: {quantidade} unidades")
gerenciar_estoque()
# Out:
# Digite o nome do produto: arroz
# Digite a quantidade de 'arroz': 100
# Deseja adicionar outro produto? (s/n): s
# Digite o nome do produto: feijao
# Digite a quantidade de 'feijao': 200
# Deseja adicionar outro produto? (s/n): s
# Digite o nome do produto: milho verde
# Digite a quantidade de 'milho verde': 50
# Deseja adicionar outro produto? (s/n): s
# Digite o nome do produto: maça
# Digite a quantidade de 'maça': 100
# Deseja adicionar outro produto? (s/n): n
# Encerrando o gerenciamento de estoque.
#
# Estoque final:
# arroz: 100 unidades
# feijao: 200 unidades
# milho verde: 50 unidades
# maça: 100 unidades

# %%
#3 Elabore um algoritmo que simule um quiz de perguntas e respostas. O programa deve apresentar uma série de perguntas ao usuário, oferecer opções de resposta e verificar se a resposta fornecida está correta. Ao final, o sistema deve exibir a pontuação total do usuário e fornecer um feedback baseado no desempenho.
perguntas = [
    {
        "pergunta": "Qual é a capital do Brasil?",
        "opcoes": ["1. Brasília", "2. Rio de Janeiro", "3. São Paulo", "4. Belo Horizonte"],
        "resposta_correta": "1"
    },
    {
        "pergunta": "Qual é o maior planeta do sistema solar?",
        "opcoes": ["1. Terra", "2. Júpiter", "3. Marte", "4. Saturno"],
        "resposta_correta": "2"
    },
    {
        "pergunta": "Quem é o melhor jogador do mundo'?",
        "opcoes": ["1. Lionel Messi", "2. CR7", "3. Neymar", "4. Vini jr"],
        "resposta_correta": "1"
    }
]

pontuacao = 0

print("Bem-vindo ao quiz!\n")
for idx, item in enumerate(perguntas):
    print(f"Pergunta {idx + 1}: {item['pergunta']}")
    for opcao in item['opcoes']:
        print(opcao)
    resposta_usuario = input("Digite o número da sua resposta: ").strip()
    if resposta_usuario == item['resposta_correta']:
        print("Resposta correta!\n")
        pontuacao += 1
    else:
        print(f"Resposta incorreta. A resposta correta era a opção {item['resposta_correta']}.\n")
print(f"Você acertou {pontuacao} de {len(perguntas)} perguntas.")
porcentagem = (pontuacao / len(perguntas)) * 100

if porcentagem == 100:
    print("Parabéns! Você acertou todas as perguntas!")
elif porcentagem >= 70:
    print("Ótimo trabalho! Você foi muito bem.")
elif porcentagem >= 50:
    print("Bom esforço! Mas ainda há espaço para melhorar.")
else:
    print("Continue estudando! Tente novamente para melhorar seu desempenho.")
# Out:
# Bem-vindo ao quiz!
#
# Pergunta 1: Qual é a capital do Brasil?
# 1. Brasília
# 2. Rio de Janeiro
# 3. São Paulo
# 4. Belo Horizonte
# Digite o número da sua resposta: 1
# Resposta correta!
#
# Pergunta 2: Qual é o maior planeta do sistema solar?
# 1. Terra
# 2. Júpiter
# 3. Marte
# 4. Saturno
# Digite o número da sua resposta: 2
# Resposta correta!
#
# Pergunta 3: Quem é o melhor jogador do mundo'?
# 1. Lionel Messi
# 2. CR7
# 3. Neymar
# 4. Vini jr
# Digite o número da sua resposta: 1
# Resposta correta!
#
# Você acertou 3 de 3 perguntas.
# Parabéns! Você acertou todas as perguntas!

# %%
#4 Crie um algoritmo que simule um sistema de controle de acesso a um edifício. O programa deve solicitar ao usuário um código de acesso e verificar se ele é válido. Caso contrário, deve permitir novas tentativas até que o número máximo de 3 tentativas seja atingido. Se o acesso for concedido, uma mensagem de boas-vindas deve ser exibida; caso contrário, uma mensagem de bloqueio deve ser apresentada.
codigo_valido = "1234"
tentativas_maximas = 3
tentativas = 0
acesso_concedido = False

while tentativas < tentativas_maximas:
    codigo_usuario = input("Por favor, insira seu código de acesso: ")
    if codigo_usuario == codigo_valido:
        print("Acesso concedido! Bem-vindo ao edifício!")
        acesso_concedido = True
        break
    else:
        tentativas += 1
        print(f"Código incorreto. Tentativa {tentativas} de {tentativas_maximas}.")

if not acesso_concedido:
    print("Acesso bloqueado. Por motivos de segurança, seu acesso foi restrito.")
# Out:
# Por favor, insira seu código de acesso: 1
# Código incorreto. Tentativa 1 de 3.
# Por favor, insira seu código de acesso: 123
# Código incorreto. Tentativa 2 de 3.
# Por favor, insira seu código de acesso: 1234
# Acesso concedido! Bem-vindo ao edifício!

# %%
#5 Desenvolva um algoritmo que ajude no planejamento de uma viagem de carro. O programa deve solicitar a distância total a ser percorrida, a capacidade do tanque de combustível do veículo e o consumo médio de combustível (km/l). Com base nessas informações, o sistema deve calcular quantas paradas para reabastecimento serão necessárias, assumindo que o motorista sempre reabastece o tanque completamente.
import math
distancia_total = float(input("Digite a distância total da viagem (em km): "))
capacidade_tanque = float(input("Digite a capacidade do tanque de combustível (em litros): "))
consumo_medio = float(input("Digite o consumo médio do veículo (km/l): "))
distancia_por_tanque = capacidade_tanque * consumo_medio
paradas = math.ceil(distancia_total / distancia_por_tanque)
print(f"Você precisará fazer aproximadamente {paradas} paradas para reabastecimento.")
# Out:
# Digite a distância total da viagem (em km): 1200
# Digite a capacidade do tanque de combustível (em litros): 55
# Digite o consumo médio do veículo (km/l): 12
# Você precisará fazer aproximadamente 2 paradas para reabastecimento.

# %%
#6 Elabore um algoritmo que simule um sistema de avaliação de filmes. O programa deve permitir que o usuário insira o título de vários filmes e uma nota de 0 a 10 para cada um. Após o usuário finalizar as entradas, o sistema deve exibir a média das notas atribuídas e listar os filmes que receberam nota superior a 8, destacando-os como altamente recomendados.
filmes = []

print("=== Sistema de Avaliação de Filmes ===")
print("Digite 'fim' para encerrar as entradas.")

while True:
    titulo = input("Digite o título do filme (ou 'fim' para encerrar): ")
    if titulo.lower() == 'fim':
        break

    try:
        nota = float(input(f"Digite a nota para '{titulo}' (0 a 10): "))
        if 0 <= nota <= 10:
            filmes.append((titulo, nota))
        else:
            print(" Nota inválida! Digite um valor entre 0 e 10.")
    except ValueError:
        print(" Entrada inválida! Digite um número válido.")

if not filmes:
    print("Nenhum filme foi avaliado.")
else:

    soma_notas = sum(nota for _, nota in filmes)
    media = soma_notas / len(filmes)


    recomendados = [titulo for titulo, nota in filmes if nota > 8]


    print("\n=== Resultados ===")
    print(f"Média das notas: {media:.2f}")

    if recomendados:
        print(" Filmes altamente recomendados (nota > 8):")
        for titulo in recomendados:
            print(f" - {titulo}")
    else:
        print("Nenhum filme recebeu nota superior a 8.")
# Out:
# === Sistema de Avaliação de Filmes ===
# Digite 'fim' para encerrar as entradas.
# Digite o título do filme (ou 'fim' para encerrar): Esqueceram de Mim
# Digite a nota para 'Esqueceram de Mim' (0 a 10): 10
# Digite o título do filme (ou 'fim' para encerrar): Gente Grande
# Digite a nota para 'Gente Grande ' (0 a 10): 10
# Digite o título do filme (ou 'fim' para encerrar): Velozes e Furiosos
# Digite a nota para 'Velozes e Furiosos ' (0 a 10): 10
# Digite o título do filme (ou 'fim' para encerrar): Alvin e os esquilos
# Digite a nota para 'Alvin e os esquilos ' (0 a 10):
#  Entrada inválida! Digite um número válido.
# Digite o título do filme (ou 'fim' para encerrar): fim
#
# === Resultados ===
# Média das notas: 10.00
#  Filmes altamente recomendados (nota > 8):
#  - Esqueceram de Mim
#  - Gente Grande
#  - Velozes e Furiosos

# %%
#7 Crie um algoritmo que simule um sistema de monitoramento de temperatura ambiente. O programa deve solicitar ao usuário que insira a temperatura registrada a cada hora durante um período de 24 horas. Ao final, o sistema deve calcular a temperatura média do dia, identificar a temperatura mais alta e a mais baixa registradas, e alertar se em algum momento a temperatura ultrapassou 30°C ou ficou abaixo de 15°C.
def monitoramento_temperatura():
    temperaturas = []

    print("Digite as temperaturas registradas a cada hora (24 entradas):")
    for hora in range(24):
        while True:
            try:
                temp = float(input(f"Hora {hora:02d}: "))
                temperaturas.append(temp)
                break
            except ValueError:
                print("Entrada inválida. Digite um número real para a temperatura.")

    media = sum(temperaturas) / 24

    temp_max = max(temperaturas)
    temp_min = min(temperaturas)

    alerta_calor = any(temp > 30 for temp in temperaturas)
    alerta_frio = any(temp < 15 for temp in temperaturas)

    print("\n--- Relatório do Monitoramento ---")
    print(f"Temperatura média do dia: {media:.2f}°C")
    print(f"Temperatura mais alta registrada: {temp_max:.2f}°C")
    print(f"Temperatura mais baixa registrada: {temp_min:.2f}°C")

    if alerta_calor:
        print(" Alerta: A temperatura ultrapassou 30°C em algum momento do dia.")
    if alerta_frio:
        print(" Alerta: A temperatura ficou abaixo de 15°C em algum momento do dia.")
    if not alerta_calor and not alerta_frio:
        print("Nenhum alerta de temperatura extrema foi registrado.")

monitoramento_temperatura()
# Out:
# Digite as temperaturas registradas a cada hora (24 entradas):
# Hora 00: -7
# Hora 01: -5
# Hora 02: -3
# Hora 03: -1
# Hora 04: 0
# Hora 05: 3
# Hora 06: 5
# Hora 07: 7
# Hora 08: 9
# Hora 09: 11
# Hora 10: 14
# Hora 11: 16
# Hora 12: 18
# Hora 13: 19
# Hora 14: 20
# Hora 15: 22
# Hora 16: 25
# Hora 17: 29
# Hora 18: 30
# Hora 19: 32
# Hora 20: 35
# Hora 21: 28
# Hora 22: 21
# Hora 23: 19
#
# --- Relatório do Monitoramento ---
# Temperatura média do dia: 14.46°C
# Temperatura mais alta registrada: 35.00°C
# Temperatura mais baixa registrada: -7.00°C
#  Alerta: A temperatura ultrapassou 30°C em algum momento do dia.
#  Alerta: A temperatura ficou abaixo de 15°C em algum momento do dia.

# %%
#8 Desenvolva um algoritmo que auxilie na organização de uma biblioteca pessoal. O programa deve permitir que o usuário insira o título e o autor de diversos livros. Após a inserção, o sistema deve oferecer a opção de buscar por livros de um autor específico e listar todos os títulos correspondentes. O processo deve continuar até que o usuário decida encerrar.
def main():
    biblioteca = []

    while True:
        print("\n--- Menu ---")
        print("1. Adicionar livro")
        print("2. Buscar livros por autor")
        print("3. Listar todos os livros")
        print("4. Encerrar")

        opcao = input("Escolha uma opção (1-4): ")

        if opcao == "1":
            titulo = input("Digite o título do livro: ").strip()
            autor = input("Digite o nome do autor: ").strip()
            biblioteca.append({"titulo": titulo, "autor": autor})
            print(f"Livro '{titulo}' de {autor} adicionado com sucesso!")

        elif opcao == "2":
            busca_autor = input("Digite o nome do autor para buscar: ").strip()
            encontrados = [livro["titulo"] for livro in biblioteca if livro["autor"].lower() == busca_autor.lower()]
            if encontrados:
                print(f"\nLivros de {busca_autor}:")
                for titulo in encontrados:
                    print(f"- {titulo}")
            else:
                print(f"Nenhum livro encontrado para o autor: {busca_autor}")

        elif opcao == "3":
            if biblioteca:
                print("\nTodos os livros cadastrados:")
                for livro in biblioteca:
                    print(f"- '{livro['titulo']}' por {livro['autor']}")
            else:
                print("Nenhum livro cadastrado ainda.")

        elif opcao == "4":
            print("Encerrando o programa. Até logo!")
            break

        else:
            print("Opção inválida. Tente novamente.")
main()
# Out:
# --- Menu ---
# 1. Adicionar livro
# 2. Buscar livros por autor
# 3. Listar todos os livros
# 4. Encerrar
# Escolha uma opção (1-4): 3
# Nenhum livro cadastrado ainda.
#
# --- Menu ---
# 1. Adicionar livro
# 2. Buscar livros por autor
# 3. Listar todos os livros
# 4. Encerrar
# Escolha uma opção (1-4): 2
# Digite o nome do autor para buscar: 1
# Nenhum livro encontrado para o autor: 1
#
# --- Menu ---
# 1. Adicionar livro
# 2. Buscar livros por autor
# 3. Listar todos os livros
# 4. Encerrar
# Escolha uma opção (1-4): 4
# Encerrando o programa. Até logo!

# %%
#9 Elabore um algoritmo que simule um sistema de gerenciamento de tarefas domésticas. O programa deve permitir que o usuário insira diferentes tarefas e atribua um nível de prioridade a cada uma (alto, médio ou baixo). O sistema deve então exibir as tarefas organizadas por ordem de prioridade, começando pelas de alta prioridade, e permitir que o usuário marque tarefas como concluídas.
def exibir_menu():
    print("\n--- Menu de Tarefas ---")
    print("1. Adicionar nova tarefa")
    print("2. Exibir tarefas por prioridade")
    print("3. Marcar tarefa como concluída")
    print("4. Encerrar")

def obter_prioridade_numero(tarefa):
    prioridade_ordem = {
        "alta": 1,
        "média": 2,
        "baixa": 3
    }
    return prioridade_ordem.get(tarefa["prioridade"], 4)

def ordenar_por_prioridade(tarefas):
    return sorted(tarefas, key=obter_prioridade_numero)

def exibir_tarefas(tarefas):
    if not tarefas:
        print("Nenhuma tarefa cadastrada.")
        return

    tarefas_ordenadas = ordenar_por_prioridade(tarefas)

    print("\n--- Tarefas Organizadas por Prioridade ---")
    for idx, tarefa in enumerate(tarefas_ordenadas, start=1):
        status = "ok" if tarefa["concluida"] else "⏳"
        print(f"{idx}. [{tarefa['prioridade'].capitalize()}] {tarefa['descricao']} - {status}")

def main():
    tarefas = []

    while True:
        exibir_menu()
        opcao = input("Escolha uma opção (1-4): ")

        if opcao == "1":
            descricao = input("Descrição da tarefa: ").strip()
            prioridade = input("Prioridade (alta, média ou baixa): ").strip().lower()
            if prioridade in ("alta", "média", "baixa"):
                tarefas.append({"descricao": descricao, "prioridade": prioridade, "concluida": False})
                print("Tarefa adicionada com sucesso!")
            else:
                print("Prioridade inválida. Use: alta, média ou baixa.")

        elif opcao == "2":
            exibir_tarefas(tarefas)

        elif opcao == "3":
            tarefas_ordenadas = ordenar_por_prioridade(tarefas)
            exibir_tarefas(tarefas)
            if tarefas:
                try:
                    num = int(input("Digite o número da tarefa a marcar como concluída: "))
                    if 1 <= num <= len(tarefas_ordenadas):
                        tarefas_ordenadas[num - 1]["concluida"] = True
                        print("Tarefa marcada como concluída!")
                    else:
                        print("Número inválido.")
                except ValueError:
                    print("Entrada inválida. Digite um número.")

        elif opcao == "4":
            print("Encerrando o sistema de tarefas. Até logo!")
            break

        else:
            print("Opção inválida. Tente novamente.")

main()
# Out:
# --- Menu de Tarefas ---
# 1. Adicionar nova tarefa
# 2. Exibir tarefas por prioridade
# 3. Marcar tarefa como concluída
# 4. Encerrar
# Escolha uma opção (1-4): 3
# Nenhuma tarefa cadastrada.
#
# --- Menu de Tarefas ---
# 1. Adicionar nova tarefa
# 2. Exibir tarefas por prioridade
# 3. Marcar tarefa como concluída
# 4. Encerrar
# Escolha uma opção (1-4): 1
# Descrição da tarefa: 2
# Prioridade (alta, média ou baixa): 4
# Prioridade inválida. Use: alta, média ou baixa.
#
# --- Menu de Tarefas ---
# 1. Adicionar nova tarefa
# 2. Exibir tarefas por prioridade
# 3. Marcar tarefa como concluída
# 4. Encerrar
# Escolha uma opção (1-4): 3
# Nenhuma tarefa cadastrada.
#
# --- Menu de Tarefas ---
# 1. Adicionar nova tarefa
# 2. Exibir tarefas por prioridade
# 3. Marcar tarefa como concluída
# 4. Encerrar
# Escolha uma opção (1-4): 2
# Nenhuma tarefa cadastrada.
#
# --- Menu de Tarefas ---
# 1. Adicionar nova tarefa
# 2. Exibir tarefas por prioridade
# 3. Marcar tarefa como concluída
# 4. Encerrar
# Escolha uma opção (1-4): 4
# Encerrando o sistema de tarefas. Até logo!

# %%
#10 Crie um algoritmo que simule um sistema de acompanhamento de hábitos saudáveis. O programa deve permitir que o usuário registre diariamente a quantidade de copos de água ingeridos e o número de minutos dedicados a atividades físicas. Ao final de uma semana, o sistema deve calcular a média diária de consumo de água e de exercícios, compará-las com as recomendações de saúde (por exemplo, 8 copos de água e 30 minutos de exercício por dia), e fornecer um feedback sobre o desempenho do usuário.
def registrar_habitos():
    agua_por_dia = []
    exercicio_por_dia = []

    print("\n--- Registro de Hábitos por 7 dias ---")
    for dia in range(1, 8):
        print(f"\nDia {dia}:")
        while True:
            try:
                agua = int(input("Quantidade de copos de água ingeridos: "))
                if agua < 0:
                    print("Digite um valor não negativo.")
                    continue
                break
            except ValueError:
                print("Digite um número inteiro válido.")
        agua_por_dia.append(agua)

        while True:
            try:
                exercicio = int(input("Minutos de atividade física realizados: "))
                if exercicio < 0:
                    print("Digite um valor não negativo.")
                    continue
                break
            except ValueError:
                print("Digite um número inteiro válido.")
        exercicio_por_dia.append(exercicio)

    return agua_por_dia, exercicio_por_dia

def calcular_medias(valores):
    return sum(valores) / len(valores)

def fornecer_feedback(media_agua, media_exercicio):
    print("\n--- Resultado Semanal ---")
    print(f"Média diária de copos de água: {media_agua:.2f}")
    print(f"Média diária de minutos de exercício: {media_exercicio:.2f}")

    print("\n--- Feedback ---")
    if media_agua >= 8:
        print("Ótimo consumo de água! Continue assim.")
    else:
        print("Tente beber mais água. O ideal são pelo menos 8 copos por dia.")

    if media_exercicio >= 30:
        print("Excelente dedicação à atividade física!")
    else:
        print("🏃‍♂️ Tente se exercitar mais. A recomendação é de pelo menos 30 minutos por dia.")

def main():
    print("=== Sistema de Acompanhamento de Hábitos Saudáveis ===")
    agua, exercicio = registrar_habitos()
    media_agua = calcular_medias(agua)
    media_exercicio = calcular_medias(exercicio)
    fornecer_feedback(media_agua, media_exercicio)

main()
# Out:
# === Sistema de Acompanhamento de Hábitos Saudáveis ===
#
# --- Registro de Hábitos por 7 dias ---
#
# Dia 1:
# Quantidade de copos de água ingeridos: 10
# Minutos de atividade física realizados: 55
#
# Dia 2:
# Quantidade de copos de água ingeridos: 15
# Minutos de atividade física realizados: 60
#
# Dia 3:
# Quantidade de copos de água ingeridos: 8
# Minutos de atividade física realizados: 45
#
# Dia 4:
# Quantidade de copos de água ingeridos: 7
# Minutos de atividade física realizados: 35
#
# Dia 5:
# Quantidade de copos de água ingeridos: 17
# Minutos de atividade física realizados: 58
#
# Dia 6:
# Quantidade de copos de água ingeridos: 11
# Minutos de atividade física realizados: 52
#
# Dia 7:
# Quantidade de copos de água ingeridos: 9
# Minutos de atividade física realizados: 45
#
# --- Resultado Semanal ---
# Média diária de copos de água: 11.00
# Média diária de minutos de exercício: 50.00
#
# --- Feedback ---
# Ótimo consumo de água! Continue assim.
# Excelente dedicação à atividade física!
